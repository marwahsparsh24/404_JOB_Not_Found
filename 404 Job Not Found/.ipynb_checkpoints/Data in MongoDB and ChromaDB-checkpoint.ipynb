# %%
# !pip install pymupdf
# Out:
# Requirement already satisfied: pymupdf in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (1.25.4)

# %% [markdown]
# ## Personal resume data

# %%
import os
import pandas as pd
import pymupdf  # This is the correct import for PyMuPDF (fitz is the old name)

# Define folder paths
RESUME_DIR = "data/resumes/"
JD_DIR = "data/job_descriptions/"
STATUS_DIR = "data/application_status/"

def extract_formatted_text(pdf_path):
    """Extract formatted text while preserving all font styles, sizes, and layout using PyMuPDF."""
    try:
        doc = pymupdf.open(pdf_path)
        formatted_text = ""
        
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)
            blocks = page.get_text("dict")["blocks"]
            
            for block in blocks:
                if block["type"] == 0:  # Only process text blocks
                    for line in block["lines"]:
                        for span in line["spans"]:
                            # Extract the text and all related formatting
                            text = span["text"]
                            font_size = span["size"]
                            font_color = span["color"]
                            font_name = span["font"]
                            is_bold = "bold" in font_name.lower()
                            is_italic = "italic" in font_name.lower()

                            # Add formatted text with details
                            formatted_text += f"Text: {text}, Font: {font_name}, Size: {font_size}, Color: {font_color}, Bold: {is_bold}, Italic: {is_italic}\n"

        return formatted_text
    except Exception as e:
        print(f"Error extracting formatted text from {pdf_path}: {e}")
        return ""

def extract_plain_text(pdf_path):
    """Extract plain text (ATS-friendly) using PyMuPDF."""
    try:
        doc = pymupdf.open(pdf_path)
        plain_text = ""
        
        for page_num in range(doc.page_count):
            page = doc.load_page(page_num)
            plain_text += page.get_text("text")
        
        return plain_text
    except Exception as e:
        print(f"Error extracting plain text from {pdf_path}: {e}")
        return ""

def read_text_file(file_path):
    """Read text from JD or application status files."""
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            return file.read().strip()
    except Exception as e:
        print(f"Error reading {file_path}: {e}")
        return ""

def process_resumes():
    """Processes resumes, JDs, and application statuses into a Pandas DataFrame."""
    data = []

    # List all files in the directories
    resume_files = sorted([file for file in os.listdir(RESUME_DIR) if file.lower().endswith('.pdf')])
    jd_files = sorted([file for file in os.listdir(JD_DIR) if file.lower().endswith('.txt')])
    status_files = sorted([file for file in os.listdir(STATUS_DIR) if file.lower().endswith('.txt')])

    # Ensure that the lengths of resume_files, jd_files, and status_files are consistent
    num_files = min(len(resume_files), len(jd_files), len(status_files))

    for i in range(num_files):
        resume_file = resume_files[i]
        jd_file = jd_files[i]
        status_file = status_files[i]

        resume_path = os.path.join(RESUME_DIR, resume_file)
        jd_path = os.path.join(JD_DIR, jd_file)
        status_path = os.path.join(STATUS_DIR, status_file)

        formatted_text = extract_formatted_text(resume_path)
        plain_text = extract_plain_text(resume_path)
        job_description = read_text_file(jd_path)
        application_status = read_text_file(status_path)

        # Store everything in a structured list
        data.append({
            "Resume File": resume_file,
            "Plain Text Resume": plain_text,
            "Formatted Resume": formatted_text,
            "Job Description": job_description,
            "Application Status": application_status
        })

    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    return df

# Run the script and get DataFrame
df = process_resumes()

# Display DataFrame
df
# Out:
# /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#     Resume File                                  Plain Text Resume  \
# 0   Resume1.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 1  Resume10.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 2   Resume2.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 3   Resume3.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 4   Resume4.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 5   Resume5.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 6   Resume6.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 7   Resume7.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 8   Resume8.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 9   Resume9.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
#
#                                     Formatted Resume  \
# 0  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 1  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 2  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 3  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 4  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 5  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 6  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 7  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 8  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 9  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
#
#                                      Job Description Application Status
# 0  Understands and articulates the business case ...           Rejected
# 1  About Us\nAlexandria Events by Invited is a pr...           Rejected
# 2  Knowing the destination isn't enough: you need...           Rejected
# 3  You’ll be joining an elite team of subject mat...           Rejected
# 4  In this position you should have the following...           Rejected
# 5  Copart is seeking a Data Science Analyst to he...           Rejected
# 6  What You'll Do:\nMinimum 1 year full-time, ana...           Rejected
# 7  Dispatch simplifies last-mile deliveries for b...           Rejected
# 8  At Sun Life, we look for optimistic people who...           Accepted
# 9  Federato is on a mission to defend the right t...           Rejected

# %%
# !pip install pymongo
# !pip install chromadb
# Out:
# Requirement already satisfied: pymongo in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (4.11.3)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from pymongo) (2.7.0)
# Requirement already satisfied: chromadb in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (0.6.3)
# Requirement already satisfied: build>=1.0.3 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.2.2.post1)
# Requirement already satisfied: pydantic>=1.9 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.10.8)
# Requirement already satisfied: chroma-hnswlib==0.7.6 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.7.6)
# Requirement already satisfied: fastapi>=0.95.2 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.115.12)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.34.0)
# Requirement already satisfied: numpy>=1.22.5 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.26.4)
# Requirement already satisfied: posthog>=2.4.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (3.23.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (4.13.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-fastapi>=0.41b0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.31.1)
# Requirement already satisfied: tokenizers>=0.13.2 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.13.2)
# Requirement already satisfied: pypika>=0.48.9 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (4.65.0)
# Requirement already satisfied: overrides>=7.3.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (7.7.0)
# Requirement already satisfied: importlib-resources in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (1.71.0)
# Requirement already satisfied: bcrypt>=4.0.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (4.3.0)
# Requirement already satisfied: typer>=0.9.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.15.2)
# Requirement already satisfied: kubernetes>=28.1.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (32.0.1)
# Requirement already satisfied: tenacity>=8.2.3 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (9.0.0)
# Requirement already satisfied: PyYAML>=6.0.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (6.0)
# Requirement already satisfied: mmh3>=4.0.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (5.1.0)
# Requirement already satisfied: orjson>=3.9.12 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (3.10.16)
# Requirement already satisfied: httpx>=0.27.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (0.28.1)
# Requirement already satisfied: rich>=10.11.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from chromadb) (13.9.4)
# Requirement already satisfied: packaging>=19.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (23.1)
# Requirement already satisfied: pyproject_hooks in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from build>=1.0.3->chromadb) (1.2.0)
# Requirement already satisfied: starlette<0.47.0,>=0.40.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from fastapi>=0.95.2->chromadb) (0.46.1)
# Requirement already satisfied: anyio in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (4.9.0)
# Requirement already satisfied: certifi in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (1.0.7)
# Requirement already satisfied: idna in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from httpx>=0.27.0->chromadb) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx>=0.27.0->chromadb) (0.14.0)
# Requirement already satisfied: six>=1.9.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.25.2)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.58.0)
# Requirement already satisfied: requests in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (2.31.0)
# Requirement already satisfied: requests-oauthlib in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3>=1.24.2 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.16)
# Requirement already satisfied: durationpy>=0.7 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from kubernetes>=28.1.0->chromadb) (0.9)
# Requirement already satisfied: coloredlogs in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: protobuf in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (5.29.4)
# Requirement already satisfied: sympy in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from onnxruntime>=1.14.1->chromadb) (1.11.1)
# Requirement already satisfied: deprecated>=1.2.6 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.18)
# Requirement already satisfied: importlib-metadata<8.7.0,>=6.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.0.0)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.69.2)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.31.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-proto==1.31.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.31.1)
# Requirement already satisfied: opentelemetry-instrumentation-asgi==0.52b1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-instrumentation==0.52b1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.52b1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: opentelemetry-util-http==0.52b1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (0.52b1)
# Requirement already satisfied: wrapt<2.0.0,>=1.0.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (1.14.1)
# Requirement already satisfied: asgiref~=3.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from opentelemetry-instrumentation-asgi==0.52b1->opentelemetry-instrumentation-fastapi>=0.41b0->chromadb) (3.8.1)
# Requirement already satisfied: monotonic>=1.5 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: backoff>=1.10.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from posthog>=2.4.0->chromadb) (1.9.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from rich>=10.11.0->chromadb) (2.15.1)
# Requirement already satisfied: click>=8.0.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from typer>=0.9.0->chromadb) (1.5.4)
# Requirement already satisfied: httptools>=0.6.3 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.4)
# Requirement already satisfied: python-dotenv>=0.13 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: watchfiles>=0.13 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.4)
# Requirement already satisfied: websockets>=10.4 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from importlib-metadata<8.7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (3.11.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->chromadb) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from requests->kubernetes>=28.1.0->chromadb) (2.0.4)
# Requirement already satisfied: sniffio>=1.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from anyio->httpx>=0.27.0->chromadb) (1.2.0)
# Requirement already satisfied: humanfriendly>=9.1 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: mpmath>=0.19 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/sparshmarwah21/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.4.8)

# %% [markdown]
# ## Storing data in MongoDB and Chroma DB

# %%
import pymongo
import chromadb
import pandas as pd
from pymongo import MongoClient

# MongoDB connection for storing formatted text
mongo_client = MongoClient("mongodb://localhost:27017/")  # Connect to MongoDB
db = mongo_client["resume_db"]
formatted_resume_collection = db["formatted_resumes"]

# ChromaDB setup for plain text
client = chromadb.PersistentClient(path="./chroma_db") 
collection = client.get_or_create_collection("plain_resumes")  # Use get_or_create_collection to avoid duplication

def store_to_chromadb_and_mongodb(df):
    """Store plain resume text in ChromaDB and formatted resume text in MongoDB, ensuring unique entries."""
    for index, row in df.iterrows():
        resume_file = row["Resume File"]
        plain_text = row["Plain Text Resume"]
        formatted_text = row["Formatted Resume"]
        job_description = row["Job Description"]
        application_status = row["Application Status"]

        # === Ensure Uniqueness in MongoDB ===
        existing_resume = formatted_resume_collection.find_one({"resume_file": resume_file})
        if existing_resume:
            # Update existing entry
            formatted_resume_collection.update_one(
                {"resume_file": resume_file},
                {"$set": {
                    "formatted_resume": formatted_text,
                    "job_description": job_description,
                    "application_status": application_status
                }}
            )
            print(f"Updated existing entry in MongoDB for: {resume_file}")
        else:
            # Insert new entry
            formatted_resume_collection.insert_one({
                "resume_file": resume_file,
                "formatted_resume": formatted_text,
                "job_description": job_description,
                "application_status": application_status
            })
            print(f"Inserted new entry in MongoDB for: {resume_file}")

        # === Ensure Uniqueness in ChromaDB ===
        existing_chroma_entry = collection.get(ids=[resume_file])  # Check if the ID already exists
        if existing_chroma_entry and existing_chroma_entry['documents']:
            # Update existing entry by first deleting and then re-adding (ChromaDB lacks direct update support)
            collection.delete(ids=[resume_file])
            print(f"Deleted existing entry in ChromaDB for: {resume_file}")

        # Add the new entry (whether new or after deletion)
        collection.add(
            documents=[plain_text],
            metadatas=[{
                "resume_file": resume_file,
                "job_description": job_description,
                "application_status": application_status
            }],
            ids=[resume_file]
        )
        print(f"Stored in ChromaDB: {resume_file}")

# Call the function to store the data in both databases
store_to_chromadb_and_mongodb(df)

# Print confirmation
print("Data has been successfully stored (ensuring uniqueness) in ChromaDB and MongoDB.")
# Out:
# Updated existing entry in MongoDB for: Resume1.pdf
# Deleted existing entry in ChromaDB for: Resume1.pdf
# Stored in ChromaDB: Resume1.pdf
# Updated existing entry in MongoDB for: Resume10.pdf
# Deleted existing entry in ChromaDB for: Resume10.pdf
# Stored in ChromaDB: Resume10.pdf
# Updated existing entry in MongoDB for: Resume2.pdf
# Deleted existing entry in ChromaDB for: Resume2.pdf
# Stored in ChromaDB: Resume2.pdf
# Updated existing entry in MongoDB for: Resume3.pdf
# Deleted existing entry in ChromaDB for: Resume3.pdf
# Stored in ChromaDB: Resume3.pdf
# Updated existing entry in MongoDB for: Resume4.pdf
# Deleted existing entry in ChromaDB for: Resume4.pdf
# Stored in ChromaDB: Resume4.pdf
# Updated existing entry in MongoDB for: Resume5.pdf
# Deleted existing entry in ChromaDB for: Resume5.pdf
# Stored in ChromaDB: Resume5.pdf
# Updated existing entry in MongoDB for: Resume6.pdf
# Deleted existing entry in ChromaDB for: Resume6.pdf
# Stored in ChromaDB: Resume6.pdf
# Updated existing entry in MongoDB for: Resume7.pdf
# Deleted existing entry in ChromaDB for: Resume7.pdf
# Stored in ChromaDB: Resume7.pdf
# Updated existing entry in MongoDB for: Resume8.pdf
# Deleted existing entry in ChromaDB for: Resume8.pdf
# Stored in ChromaDB: Resume8.pdf
# Updated existing entry in MongoDB for: Resume9.pdf
# Deleted existing entry in ChromaDB for: Resume9.pdf
# Stored in ChromaDB: Resume9.pdf
# Data has been successfully stored (ensuring uniqueness) in ChromaDB and MongoDB.

# %% [markdown]
# ### Retrieval of data

# %%
import pandas as pd
from pymongo import MongoClient

# MongoDB connection string (adjust it as needed)
MONGO_URI = "mongodb://localhost:27017"
DATABASE_NAME = "resume_db"
FORMATTED_COLLECTION = "formatted_resumes"

# Connect to MongoDB
client = MongoClient(MONGO_URI)
db = client[DATABASE_NAME]
formatted_resume_collection = db[FORMATTED_COLLECTION]

def retrieve_formatted_resumes_as_df():
    """Retrieve unique formatted resume data from MongoDB and return it as a DataFrame"""
    
    # Retrieve all documents from the collection
    formatted_resumes = formatted_resume_collection.find() 
    
    # Convert the results into a list of dictionaries while ensuring unique entries
    resume_list = []
    seen_files = set()  # To track unique resume files
    
    for resume in formatted_resumes:
        resume_file = resume['resume_file']
        
        # Only append if the resume_file hasn't been encountered before
        if resume_file not in seen_files:
            seen_files.add(resume_file)
            resume_list.append({
                "Resume File": resume['resume_file'],
                "Formatted Resume": resume['formatted_resume'],
                "Job Description": resume['job_description'],
                "Application Status": resume['application_status']
            })
    
    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(resume_list)
    return df

# Example usage: retrieve unique formatted resumes as a DataFrame
formatted_resume_df = retrieve_formatted_resumes_as_df()
formatted_resume_df
# Out:
#     Resume File                                   Formatted Resume  \
# 0   Resume1.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 1  Resume10.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 2   Resume2.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 3   Resume3.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 4   Resume4.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 5   Resume5.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 6   Resume6.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 7   Resume7.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 8   Resume8.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
# 9   Resume9.pdf  Text: Sparsh Marwah , Font: TimesNewRomanPS-Bo...
#
#                                      Job Description Application Status
# 0  Understands and articulates the business case ...           Rejected
# 1  About Us\nAlexandria Events by Invited is a pr...           Rejected
# 2  Knowing the destination isn't enough: you need...           Rejected
# 3  You’ll be joining an elite team of subject mat...           Rejected
# 4  In this position you should have the following...           Rejected
# 5  Copart is seeking a Data Science Analyst to he...           Rejected
# 6  What You'll Do:\nMinimum 1 year full-time, ana...           Rejected
# 7  Dispatch simplifies last-mile deliveries for b...           Rejected
# 8  At Sun Life, we look for optimistic people who...           Accepted
# 9  Federato is on a mission to defend the right t...           Rejected

# %%
import chromadb
import pandas as pd

# Initialize ChromaDB client and collection
client = chromadb.PersistentClient(path="./chroma_db")  # Use the correct path if needed
collection = client.get_or_create_collection(name="plain_resumes")

def retrieve_all_resumes():
    """Retrieve all resumes stored in ChromaDB and return as a DataFrame"""
    results = collection.get()  # Retrieves all stored documents
    
    # Convert results to a structured DataFrame
    resume_list = []
    for i in range(len(results['documents'])):
        resume_list.append({
            "Resume File": results['ids'][i],
            "Plain Text Resume": results['documents'][i],
            "Metadata": results['metadatas'][i]  # Contains metadata like resume_file, job_description, etc.
        })
    
    df = pd.DataFrame(resume_list)
    return df

# Retrieve all resumes
plain_resumes_df = retrieve_all_resumes()
plain_resumes_df
# Out:
#     Resume File                                  Plain Text Resume  \
# 0   Resume1.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 1  Resume10.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 2   Resume2.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 3   Resume3.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 4   Resume4.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 5   Resume5.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 6   Resume6.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 7   Resume7.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 8   Resume8.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
# 9   Resume9.pdf  Sparsh Marwah \nBoston, MA 02130 | marwah.sp@n...
#
#                                             Metadata
# 0  {'application_status': 'Rejected', 'job_descri...
# 1  {'application_status': 'Rejected', 'job_descri...
# 2  {'application_status': 'Rejected', 'job_descri...
# 3  {'application_status': 'Rejected', 'job_descri...
# 4  {'application_status': 'Rejected', 'job_descri...
# 5  {'application_status': 'Rejected', 'job_descri...
# 6  {'application_status': 'Rejected', 'job_descri...
# 7  {'application_status': 'Rejected', 'job_descri...
# 8  {'application_status': 'Accepted', 'job_descri...
# 9  {'application_status': 'Rejected', 'job_descri...
